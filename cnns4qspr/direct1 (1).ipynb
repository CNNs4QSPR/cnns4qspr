# %%
import pandas as pd
import numpy as np
from biopandas.mol2 import PandasMol2

# %%
from biopandas.pdb import PandasPdb
ppdb = PandasPdb().fetch_pdb('3eiy')

# %%
import zipfile
from zipfile import ZipFile
zf=zipfile.ZipFile('/Users/nisargjoshi/Downloads/file.zip')

# %%
print(zf.namelist())
# Out:
# ['1a0rP02', '1a1vA03', '1a0hA02', '1a0rP01', '1a1vA01', '1a1aB00', '1a1vA02', '1a0hA01', '1a0pA01', '1a0cA00', '1a0iA01', '1a0iA02', '1a1wA00', '1a1xA00', '1a0sP00', '1a0rB00', '1a0gA02', '1a00B00', '1a1iA01', '1a2oA01', '1a0iA03', '1a2fA02', '1a1rA02', '1a02F00']

# %%
list45=[]

# %%
for i in zf.namelist():
    openf=ppdb.read_pdb('/Users/nisargjoshi/Downloads/file/'+i)
    list45.append(openf)
    #print(openf)

# %%
for o in list45:
    print(o)

# %%
list45[0].df['ATOM']['atom_number'].values
# Out:
# array([3022, 3023, 3024, 3025, 3026, 3027, 3028, 3029, 3030, 3031, 3032,
#        3033, 3034, 3035, 3036, 3037, 3038, 3039, 3040, 3041, 3042, 3043,
#        3044, 3045, 3046, 3047, 3048, 3049, 3050, 3051, 3052, 3053, 3054,
#        3055, 3056, 3057, 3058, 3059, 3060, 3061, 3062, 3063, 3064, 3065,
#        3066, 3067, 3068, 3069, 3070, 3071, 3072, 3073, 3074, 3075, 3076,
#        3077, 3078, 3079, 3080, 3081, 3082, 3083, 3084, 3085, 3086, 3087,
#        3088, 3089, 3090, 3091, 3092, 3093, 3094, 3095, 3096, 3097, 3098,
#        3099, 3100, 3101, 3102, 3103, 3104, 3105, 3106, 3107, 3108, 3109,
#        3110, 3111, 3112, 3113, 3114, 3115, 3116, 3117, 3118, 3119, 3120,
#        3121, 3122, 3123, 3124, 3125, 3126, 3127, 3128, 3129, 3130, 3131,
#        3132, 3133, 3134, 3135, 3136, 3137, 3138, 3139, 3140, 3141, 3142,
#        3143, 3144, 3145, 3146, 3147, 3148, 3149, 3150, 3151, 3152, 3153,
#        3154, 3155, 3156, 3157, 3158, 3159, 3160, 3161, 3162, 3163, 3164,
# ...

# %%
#q1= list45[0].df['ATOM']['residue_name'].values

# %%
residue_names={'r1':list45[0].df['ATOM']['residue_name'].values, 'r2':list45[1].df['ATOM']['residue_name'].values, 'r3':list45[2].df['ATOM']['residue_name'].values, 'r4': list45[3].df['ATOM']['residue_name'].values, 'r5':list45[4].df['ATOM']['residue_name'].values, 'r6':list45[5].df['ATOM']['residue_name'].values, 'r7':list45[6].df['ATOM']['residue_name'].values, 'r8':list45[7].df['ATOM']['residue_name'].values, 'r9':list45[8].df['ATOM']['residue_name'].values, 'r10':list45[9].df['ATOM']['residue_name'].values, 'r11':list45[10].df['ATOM']['residue_name'].values, 'r12':list45[11].df['ATOM']['residue_name'].values, 'r13':list45[12].df['ATOM']['residue_name'].values, 'r14':list45[13].df['ATOM']['residue_name'].values, 'r15':list45[14].df['ATOM']['residue_name'].values, 'r16':list45[15].df['ATOM']['residue_name'].values, 'r17':list45[16].df['ATOM']['residue_name'].values, 'r18':list45[17].df['ATOM']['residue_name'].values, 'r19':list45[18].df['ATOM']['residue_name'].values, 'r20':list45[19].df['ATOM']['residue_name'].values, 'r21':list45[20].df['ATOM']['residue_name'].values, 'r22':list45[21].df['ATOM']['residue_name'].values, 'r23':list45[22].df['ATOM']['residue_name'].values, 'r24':list45[23].df['ATOM']['residue_name'].values}

# %%
atom_numbers={'n1':list45[0].df['ATOM']['atom_number'].values, 'n2':list45[1].df['ATOM']['atom_number'].values, 'n3':list45[2].df['ATOM']['atom_number'].values, 'n4': list45[3].df['ATOM']['atom_number'].values, 'n5':list45[4].df['ATOM']['atom_number'].values, 'n6':list45[5].df['ATOM']['atom_number'].values, 'n7':list45[6].df['ATOM']['atom_number'].values, 'n8':list45[7].df['ATOM']['atom_number'].values, 'n9':list45[8].df['ATOM']['atom_number'].values, 'n10':list45[9].df['ATOM']['atom_number'].values, 'n11':list45[10].df['ATOM']['atom_number'].values, 'n12':list45[11].df['ATOM']['atom_number'].values, 'n13':list45[12].df['ATOM']['atom_number'].values, 'n14':list45[13].df['ATOM']['atom_number'].values, 'n15':list45[14].df['ATOM']['atom_number'].values, 'n16':list45[15].df['ATOM']['atom_number'].values, 'n17':list45[16].df['ATOM']['atom_number'].values, 'n18':list45[17].df['ATOM']['atom_number'].values, 'n19':list45[18].df['ATOM']['atom_number'].values, 'n20':list45[19].df['ATOM']['atom_number'].values, 'n21':list45[20].df['ATOM']['atom_number'].values, 'n22':list45[21].df['ATOM']['atom_number'].values, 'n23':list45[22].df['ATOM']['atom_number'].values, 'n24':list45[23].df['ATOM']['atom_number'].values}

# %%
atom_types={'q1':list45[0].df['ATOM']['atom_name'].values, 'q2':list45[1].df['ATOM']['atom_name'].values, 'q3':list45[2].df['ATOM']['atom_name'].values, 'q4': list45[3].df['ATOM']['atom_name'].values, 'q5':list45[4].df['ATOM']['atom_name'].values, 'q6':list45[5].df['ATOM']['atom_name'].values, 'q7':list45[6].df['ATOM']['atom_name'].values, 'q8':list45[7].df['ATOM']['atom_name'].values, 'q9':list45[8].df['ATOM']['atom_name'].values, 'q10':list45[9].df['ATOM']['atom_name'].values, 'q11':list45[10].df['ATOM']['atom_name'].values, 'q12':list45[11].df['ATOM']['atom_name'].values, 'q13':list45[12].df['ATOM']['atom_name'].values, 'q14':list45[13].df['ATOM']['atom_name'].values, 'q15':list45[14].df['ATOM']['atom_name'].values, 'q16':list45[15].df['ATOM']['atom_name'].values, 'q17':list45[16].df['ATOM']['atom_name'].values, 'q18':list45[17].df['ATOM']['atom_name'].values, 'q19':list45[18].df['ATOM']['atom_name'].values, 'q20':list45[19].df['ATOM']['atom_name'].values, 'q21':list45[20].df['ATOM']['atom_name'].values, 'q22':list45[21].df['ATOM']['atom_name'].values, 'q23':list45[22].df['ATOM']['atom_name'].values, 'q24':list45[23].df['ATOM']['atom_name'].values}

# %%
main1=(atom_types['q1'], atom_types['q2'])
main1
# Out:
# (array(['N', 'CA', 'C', 'O', 'CB', 'CG', 'CD', 'NE', 'CZ', 'NH1', 'NH2',
#         'N', 'CA', 'C', 'O', 'CB', 'CG', 'CD', 'NE', 'CZ', 'NH1', 'NH2',
#         'N', 'CA', 'C', 'O', 'CB', 'CG1', 'CG2', 'CD1', 'N', 'CA', 'C',
#         'O', 'CB', 'CG', 'CD', 'NE', 'CZ', 'NH1', 'NH2', 'N', 'CA', 'C',
#         'O', 'CB', 'CG', 'CD', 'NE', 'CZ', 'NH1', 'NH2', 'N', 'CA', 'C',
#         'O', 'CB', 'CG', 'CD', 'OE1', 'OE2', 'N', 'CA', 'C', 'O', 'CB',
#         'CG', 'CD', 'NE', 'CZ', 'NH1', 'NH2', 'N', 'CA', 'C', 'O', 'CB',
#         'CG', 'OD1', 'ND2', 'N', 'CA', 'C', 'O', 'CB', 'CG', 'CD', 'CE',
#         'NZ', 'N', 'CA', 'C', 'O', 'CB', 'CG', 'SD', 'CE', 'N', 'CA', 'C',
#         'O', 'CB', 'N', 'CA', 'C', 'O', 'CB', 'N', 'CA', 'C', 'O', 'CB',
#         'N', 'CA', 'C', 'O', 'CB', 'CG', 'CD', 'CE', 'NZ', 'N', 'CA', 'C',
#         'O', 'CB', 'OG', 'N', 'CA', 'C', 'O', 'CB', 'CG', 'CD', 'NE', 'CZ',
#         'NH1', 'NH2', 'N', 'CA', 'C', 'O', 'CB', 'CG', 'OD1', 'ND2', 'N',
# ...

# %%
for residue in residue_names:
    array_residue_names=residue_names[residue]
    print(array_residue_names)
# Out:
# ['ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG'
#  'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ILE' 'ILE'
#  'ILE' 'ILE' 'ILE' 'ILE' 'ILE' 'ILE' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG'
#  'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG'
#  'ARG' 'ARG' 'ARG' 'ARG' 'GLU' 'GLU' 'GLU' 'GLU' 'GLU' 'GLU' 'GLU' 'GLU'
#  'GLU' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG'
#  'ASN' 'ASN' 'ASN' 'ASN' 'ASN' 'ASN' 'ASN' 'ASN' 'LYS' 'LYS' 'LYS' 'LYS'
#  'LYS' 'LYS' 'LYS' 'LYS' 'LYS' 'MET' 'MET' 'MET' 'MET' 'MET' 'MET' 'MET'
#  'MET' 'ALA' 'ALA' 'ALA' 'ALA' 'ALA' 'ALA' 'ALA' 'ALA' 'ALA' 'ALA' 'ALA'
#  'ALA' 'ALA' 'ALA' 'ALA' 'LYS' 'LYS' 'LYS' 'LYS' 'LYS' 'LYS' 'LYS' 'LYS'
#  'LYS' 'SER' 'SER' 'SER' 'SER' 'SER' 'SER' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG'
#  'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ASN' 'ASN' 'ASN' 'ASN' 'ASN' 'ASN'
#  'ASN' 'ASN' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG'
# ...

# %%
for number in atom_numbers:
    array_atom_numbers=atom_numbers[number]
    print(array_atom_numbers)
# Out:
# [3022 3023 3024 3025 3026 3027 3028 3029 3030 3031 3032 3033 3034 3035
#  3036 3037 3038 3039 3040 3041 3042 3043 3044 3045 3046 3047 3048 3049
#  3050 3051 3052 3053 3054 3055 3056 3057 3058 3059 3060 3061 3062 3063
#  3064 3065 3066 3067 3068 3069 3070 3071 3072 3073 3074 3075 3076 3077
#  3078 3079 3080 3081 3082 3083 3084 3085 3086 3087 3088 3089 3090 3091
#  3092 3093 3094 3095 3096 3097 3098 3099 3100 3101 3102 3103 3104 3105
#  3106 3107 3108 3109 3110 3111 3112 3113 3114 3115 3116 3117 3118 3119
#  3120 3121 3122 3123 3124 3125 3126 3127 3128 3129 3130 3131 3132 3133
#  3134 3135 3136 3137 3138 3139 3140 3141 3142 3143 3144 3145 3146 3147
#  3148 3149 3150 3151 3152 3153 3154 3155 3156 3157 3158 3159 3160 3161
#  3162 3163 3164 3165 3166 3167 3168 3169 3170 3171 3172 3173 3174 3175
#  3176 3177 3178 3179 3180 3181 3182 3183 3184 3185 3186 3187 3188 3189
#  3190 3191 3192 3193 3194 3195 3196 3197 3198 3199 3200 3201 3202 3203
# ...

# %%
for array in atom_types:
    main_atom_types=atom_types[array]
    print(main_atom_types)
# Out:
# ['N' 'CA' 'C' 'O' 'CB' 'CG' 'CD' 'NE' 'CZ' 'NH1' 'NH2' 'N' 'CA' 'C' 'O'
#  'CB' 'CG' 'CD' 'NE' 'CZ' 'NH1' 'NH2' 'N' 'CA' 'C' 'O' 'CB' 'CG1' 'CG2'
#  'CD1' 'N' 'CA' 'C' 'O' 'CB' 'CG' 'CD' 'NE' 'CZ' 'NH1' 'NH2' 'N' 'CA' 'C'
#  'O' 'CB' 'CG' 'CD' 'NE' 'CZ' 'NH1' 'NH2' 'N' 'CA' 'C' 'O' 'CB' 'CG' 'CD'
#  'OE1' 'OE2' 'N' 'CA' 'C' 'O' 'CB' 'CG' 'CD' 'NE' 'CZ' 'NH1' 'NH2' 'N'
#  'CA' 'C' 'O' 'CB' 'CG' 'OD1' 'ND2' 'N' 'CA' 'C' 'O' 'CB' 'CG' 'CD' 'CE'
#  'NZ' 'N' 'CA' 'C' 'O' 'CB' 'CG' 'SD' 'CE' 'N' 'CA' 'C' 'O' 'CB' 'N' 'CA'
#  'C' 'O' 'CB' 'N' 'CA' 'C' 'O' 'CB' 'N' 'CA' 'C' 'O' 'CB' 'CG' 'CD' 'CE'
#  'NZ' 'N' 'CA' 'C' 'O' 'CB' 'OG' 'N' 'CA' 'C' 'O' 'CB' 'CG' 'CD' 'NE' 'CZ'
#  'NH1' 'NH2' 'N' 'CA' 'C' 'O' 'CB' 'CG' 'OD1' 'ND2' 'N' 'CA' 'C' 'O' 'CB'
#  'CG' 'CD' 'NE' 'CZ' 'NH1' 'NH2' 'N' 'CA' 'C' 'O' 'CB' 'CG' 'CD' 'NE' 'CZ'
#  'NH1' 'NH2' 'N' 'CA' 'C' 'O' 'CB' 'CG' 'CD' 'NE' 'CZ' 'NH1' 'NH2' 'N'
#  'CA' 'C' 'O' 'CB' 'CG' 'CD' 'OE1' 'OE2' 'N' 'CA' 'C' 'O' 'CB' 'CG' 'CD1'
# ...

# %%
atom_types['q24']
# Out:
# array(['N', 'CA', 'C', 'O', 'CB', 'CG', 'CD', 'NE', 'CZ', 'NH1', 'NH2',
#        'N', 'CA', 'C', 'O', 'CB', 'CG', 'CD', 'NE', 'CZ', 'NH1', 'NH2',
#        'N', 'CA', 'C', 'O', 'CB', 'CG1', 'CG2', 'CD1', 'N', 'CA', 'C',
#        'O', 'CB', 'CG', 'CD', 'NE', 'CZ', 'NH1', 'NH2', 'N', 'CA', 'C',
#        'O', 'CB', 'CG', 'CD', 'NE', 'CZ', 'NH1', 'NH2', 'N', 'CA', 'C',
#        'O', 'CB', 'CG', 'CD', 'OE1', 'OE2', 'N', 'CA', 'C', 'O', 'CB',
#        'CG', 'CD', 'NE', 'CZ', 'NH1', 'NH2', 'N', 'CA', 'C', 'O', 'CB',
#        'CG', 'OD1', 'ND2', 'N', 'CA', 'C', 'O', 'CB', 'CG', 'CD', 'CE',
#        'NZ', 'N', 'CA', 'C', 'O', 'CB', 'CG', 'SD', 'CE', 'N', 'CA', 'C',
#        'O', 'CB', 'N', 'CA', 'C', 'O', 'CB', 'N', 'CA', 'C', 'O', 'CB',
#        'N', 'CA', 'C', 'O', 'CB', 'CG', 'CD', 'CE', 'NZ', 'N', 'CA', 'C',
#        'O', 'CB', 'OG', 'N', 'CA', 'C', 'O', 'CB', 'CG', 'CD', 'NE', 'CZ',
#        'NH1', 'NH2', 'N', 'CA', 'C', 'O', 'CB', 'CG', 'OD1', 'ND2', 'N',
# ...

# %%
c1_x = []
c2_x = []
c3_x = []

# %%
for i in list45:
    c1 = i.df['ATOM']['x_coord'].values.tolist()
    c2 = i.df['ATOM']['y_coord'].values.tolist()
    c3 = i.df['ATOM']['z_coord'].values.tolist()
    c1_x.append(c1)
    c2_x.append(c2)
    c3_x.append(c3)

# %%
atm_lst = []

# %%
for i in range(len(c1_x)):
    for j in range(len(c1_x[i])):
        ls = [c1_x[i][j], c2_x[i][j], c3_x[i][j]]
        atm_lst.append(ls)

# %%
print(atm_lst)
# Out:
# [[58.293, 29.583, 30.684], [58.515, 28.109, 30.628], [57.422, 27.413, 31.425], [57.107, 27.829, 32.539], [59.896, 27.723, 31.199], [60.212, 26.211, 31.121], [61.281, 25.746, 32.112], [62.65, 26.12, 31.744], [63.258, 27.251, 32.108], [62.631, 28.149, 32.865], [64.493, 27.508, 31.688], [56.881, 26.331, 30.879], [55.829, 25.578, 31.547], [56.176, 25.22, 32.994], [55.29, 25.159, 33.851], [55.524, 24.29, 30.781], [56.733, 23.376, 30.612], [56.336, 21.911, 30.428], [55.359, 21.703, 29.356], [55.5, 22.114, 28.095], [56.59, 22.772, 27.709], [54.54, 21.866, 27.213], [57.46, 24.999, 33.271], [57.871, 24.626, 34.619], [57.957, 25.807, 35.574], [57.4, 25.77, 36.653], [59.158, 23.778, 34.608], [58.861, 22.449, 33.888], [59.686, 23.601, 36.028], [59.57, 21.222, 34.414], [58.601, 26.878, 35.143], [58.718, 28.08, 35.966], [57.323, 28.555, 36.387], [57.164, 29.211, 37.415], [59.483, 29.171, 35.192], [59.069, 30.617, 35.448], [59.921, 31.56, 34.6], [59.245, 32.831, 34.333], [59.859, 34.008, 34.191], [
# ...

# %%
print(len(atm_lst))
# Out:
# 10608
